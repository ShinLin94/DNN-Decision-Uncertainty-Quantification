# %% [markdown]
# Run this code on HPC

# %%
import torch
import kagglehub

# 1. Download/get the exact directory path (this automatically resolves to the '2' folder)
model_dir = kagglehub.model_download("vickykiwisy/res18b3-block-3456-5050/pyTorch/default")

# 2. Path to the best model weights
checkpoint_path = f"{model_dir}/best_model_train_RES18_B3_BLOCK3456.pth"

# 3. Load the checkpoint
checkpoint = torch.load(checkpoint_path, map_location='cpu')

print("Successfully loaded checkpoint!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import torch
# ----> 2 import kagglehub
#       4 # 1. Download/get the exact directory path (this automatically resolves to the '2' folder)
#       5 model_dir = kagglehub.model_download("vickykiwisy/res18b3-block-3456-5050/pyTorch/default")
#
# ModuleNotFoundError: No module named 'kagglehub'
